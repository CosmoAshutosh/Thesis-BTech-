# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('steam_reviews.csv')

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  app_id                  app_name  review_id  \
# 0             3           3  292030  The Witcher 3: Wild Hunt   85184605
# 1             5           5  292030  The Witcher 3: Wild Hunt   85184171
# 2             6           6  292030  The Witcher 3: Wild Hunt   85184064
# 3            18          18  292030  The Witcher 3: Wild Hunt   85180436
# 4            20          20  292030  The Witcher 3: Wild Hunt   85179753
#
#   language                                             review  \
# 0  english  One of the best RPG's of all time, worthy of a...
# 1  english             good story, good graphics. lots to do.
# 2  english                                           dis gud,
# 3  english  favorite game of all time cant wait for the Ne...
# 4  english                          Why wouldn't you get this
#
#    timestamp_created  timestamp_updated  recommended  ...  steam_purchase  \
# 0         1611379970         1611379970         True  ...            True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9635437 entries, 0 to 9635436
# Data columns (total 24 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unnamed: 0.1                    int64
#  1   Unnamed: 0                      int64
#  2   app_id                          int64
#  3   app_name                        object
#  4   review_id                       int64
#  5   language                        object
#  6   review                          object
#  7   timestamp_created               int64
#  8   timestamp_updated               int64
#  9   recommended                     bool
#  10  votes_helpful                   int64
#  11  votes_funny                     int64
#  12  weighted_vote_score             float64
#  13  comment_count                   int64
#  14  steam_purchase                  bool
#  15  received_for_free               bool
#  16  written_during_early_access     bool
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'app_id', 'app_name', 'review_id',
#        'language', 'review', 'timestamp_created', 'timestamp_updated',
#        'recommended', 'votes_helpful', 'votes_funny', 'weighted_vote_score',
#        'comment_count', 'steam_purchase', 'received_for_free',
#        'written_during_early_access', 'author.steamid',
#        'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played'],
#       dtype='object')

# %%
print("Total no of games in the dataset is :", len(df['app_name'].unique()))
# Out:
# Total no of games in the dataset is : 315

# %%
for app, count in df['app_name'].value_counts().items():
    print(f"No of Reviews of {app} is : {count}")
# Out:
# No of Reviews of Tom Clancy's Rainbow Six Siege is : 371154
# No of Reviews of Terraria is : 370240
# No of Reviews of Garry's Mod is : 331621
# No of Reviews of Grand Theft Auto V is : 319751
# No of Reviews of PLAYERUNKNOWN'S BATTLEGROUNDS is : 317846
# No of Reviews of Among Us is : 295991
# No of Reviews of Rust is : 283777
# No of Reviews of Rocket League is : 248720
# No of Reviews of PAYDAY 2 is : 187096
# No of Reviews of ARK: Survival Evolved is : 184576
# No of Reviews of Stardew Valley is : 172698
# No of Reviews of The Elder Scrolls V: Skyrim is : 160233
# No of Reviews of The Witcher 3: Wild Hunt is : 151460
# No of Reviews of Dead by Daylight is : 143988
# No of Reviews of Fallout 4 is : 139127
# No of Reviews of Phasmophobia is : 129630
# No of Reviews of No Man's Sky is : 116212
# No of Reviews of Hollow Knight is : 109538
# No of Reviews of Portal 2 is : 107466
# No of Reviews of Sid Meier's Civilization V is : 104257
# ...

# %%
import gensim
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import nltk
import re
import emoji

# %%
# Count the number of reviews for each game
review_counts = df['app_name'].value_counts()

# Filter the games to include only those with review counts between 10,000 and 13,000
filtered_games = review_counts[(review_counts >= 13000) & (review_counts <= 13900)].index

# Randomly select 5 games from the filtered list
random_games = filtered_games.to_series().tolist()
# Out:
# ['Resident Evil 7 Biohazard',
#  'GRIS',
#  'Call of Duty: WWII',
#  'Pathfinder: Kingmaker',
#  'Duck Game']

# %%
selected_reviews = df[df['app_name'].isin(random_games)]

# Save the reviews to a CSV file
selected_reviews.to_csv('selected_game_reviews.csv', index=False)

# print("Reviews saved to 'selected_game_reviews.csv'")

# %% [markdown]
# ## -------------------------------------------------------------------------------------------

# %%
def preprocess(text):
    # Tokenize the text
    tokens = word_tokenize(text)
    # Convert to lower case
    tokens = [word.lower() for word in tokens]
    # Remove punctuation
    tokens = [word for word in tokens if word.isalpha()]
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    return tokens

# Apply preprocessing to all reviews
processed_reviews = [preprocess(review) for review in reviews]

# %%
processed_reviews
# Out:
# [['nice',
#   'game',
#   'strory',
#   'music',
#   'sounds',
#   'amazing',
#   'like',
#   'turn',
#   'base',
#   'game',
#   'like',
#   'xcom',
#   'game',
#   'worth'],
#  ['great',
#   'soundtrack',
#   'probably',
#   'best',
#   'game',
#   'date',
#   'similar',
#   'xcom',
#   'broad',
#   'sense',
#   'thematically',
#   'game',
#   'enjoy',
#   'turn',
#   'based',
#   'small',
#   'unit',
#   'strategy',
#   'games',
#   'wo',
#   'disapoint'],
#  ['seems',
#   'like',
#   'whole',
#   'point',
#   'game',
#   'turned',
#   'sniper',
#   'fight',
#   'knife',
#   'tutorial',
#   'clear',
#   'mud',
#   'player',
#   'piss',
#   'damage',
#   'per',
#   'hit',
#   'weapon',
#   'enemies',
#   'longer',
#   'range',
#   'weapons',
#   'always',
#   'hit',
#   'high',
#   'damage',
#   'ui',
#   'fucking',
#   'terrible',
#   'assets',
#   'especially',
#   'enemy',
#   'models',
#   'look',
#   'cheap',
#   'nasty',
#   'mechanics',
#   'basic',
#   'typical',
# ...

# %%
# Train a Word2Vec model
model = Word2Vec(sentences=processed_reviews, vector_size=100, window=5, min_count=5, workers=4)

# Save the model for later use
model.save("word2vec.model")

# %%
# Load the model if needed
model = Word2Vec.load("word2vec.model")

# Find the vector for a specific word
vector = model.wv['game']  # Example word

# Find words similar to a given word
similar_words = model.wv.most_similar('best')

# Print the results
print("Vector for 'game':", vector)
print("Words similar to 'best':", similar_words)
# Out:
# Vector for 'game': [-0.26320785  0.39320588  0.33853292  0.11013821 -0.41633186 -0.86856097
#   0.7110176   0.58415353 -0.50900525 -0.4454975   0.13968104 -0.9288783
#   0.21098806  0.5694406   0.00163625 -0.2584457   0.05945758 -0.2509776
#  -0.6060656  -1.0715486   0.57043034  0.5323767   0.5235756   0.05662216
#  -0.12536213  0.0996154  -0.69710314  0.19643274 -0.22508232 -0.05095313
#   0.49275783  0.13903403  0.60598433 -0.40587395 -0.22313443  0.7660361
#   0.41329467  0.0519441  -0.8394372  -0.39048496 -0.02609525 -0.14784011
#  -0.58845943  0.273232    0.18118654 -0.18156143 -0.26573628  0.03575097
#   0.57617474 -0.0167937   0.3653198  -0.16657996 -0.06472924  0.03766017
#  -0.8051893  -0.04181689  0.20806292 -0.7423501  -0.3093386   0.07946096
#   0.3575925  -0.09711219  0.28231815 -0.05594637 -0.72788227  0.79495686
#   0.04325614  0.22478811 -1.0960855   0.4981679  -0.5614153   0.67101276
#  -0.02398205 -0.03957862  0.6278374   0.32032377  0.27889937  0.20745125
# ...
